# %% [markdown]
# <a href="https://colab.research.google.com/github/ShinAsakawa/ShinAsakawa.github.io/blob/master/2025notebooks/2025_0926tiktoken_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import tiktoken
except ImportError:
    # !pip install tiktoken
    import tiktoken

# %%
import tiktoken

# モデルに対応したエンコーディングを取得
tokenizer = tiktoken.encoding_for_model("gpt-4")

# テキストをトークン化してカウント
inp = "吾輩は猫である。名前はまだ無い。"
inp_ids = tokenizer.encode(inp)

print(f"入力文: {inp}")
print(f"トークン数: {len(inp_ids)}")
print(f"トークン IDs: {inp_ids}")
print(f"逆変換: {tokenizer.decode(token_ids)}")

# %%
# 例えばどのように変換されているかを見てみる
tokenizer.decode([7305,122]), tokenizer.decode([164,120,102])

# %%
# tokenizer  には以下のような関数や定数などが定義されている
for k in dir(tokenizer):
    if not str(k).startswith('_'):
        print(k)

# %%
# さらに例示
tokenizer.n_vocab

# %%
# 利用可能なエンコーディング一覧
print("利用可能なエンコーディング:")
for encoding_name in tiktoken.list_encoding_names():
    print(f"  - {encoding_name}")

# %%
# モデルごとの対応
model_encodings = {
    "gpt-4": "cl100k_base",
    "gpt-3.5-turbo": "cl100k_base",
    "text-embedding-ada-002": "cl100k_base",
    "gpt-2": "gpt2",
}

# 特定のエンコーディングを直接使用
tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
import os
HOME = os.environ['HOME']

import IPython
isColab = 'google.colab' in str(IPython.get_ipython())

if isColab:
    # 準備作業
    # !apt-get install mecab libmecab-dev mecab-ipadic-utf8 -y   # apt-get でライブラリを持ってきてコンパイル，インストール
    # !pip install mecab-python3                                 # pip で python にライブラリをインポート
    # !ln -s /etc/mecabrc /usr/local/etc/mecabrc                 # MeCab の rc ファイルを正しい場所にシンボリックリンクを貼る

import MeCab
mecab_wakati = MeCab.Tagger('-Owakati').parse

# https://www.manythings.org/anki/
if isColab:
    if not os.path.exists('jpn-eng.zip'):
        # !wget https://www.manythings.org/anki/jpn-eng.zip
        # !unzip jpn-eng.zip
        # !rm _about.txt
    if not os.path.exists('cmn-eng.zip'):
        # !wget https://www.manythings.org/anki/cmn-eng.zip
        # !unzip cmn-eng.zip
        # !rm _about.txt
    if not os.path.exists('kor-eng.zip'):
        # !wget https://www.manythings.org/anki/kor-eng.zip
        # !unzip kor-eng.zip
        # !rm _about.txt

# %%
try:
    import gensim
except ImportError:
    # !pip install gensim
    import gensim
