# %% [markdown]
# <a href="https://colab.research.google.com/github/ShinAsakawa/ShinAsakawa.github.io/blob/master/2022notebooks/2022_0703iwashita_yoshihara_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# - tile: `2022_0703iwashita_yoshihara_demo.ipynb'
# - data: 2022_0703
# - author: 浅川伸一
# ---
#
# # SNOW の文章をいじってみる

# %%
import torch
try:
    import bit
except ImportError:
    # !pip install ipynbname --upgrade > /dev/null 2>&1 
    # !git clone https://github.com/ShinAsakawa/bit.git
import bit

isColab = bit.isColab
HOME = bit.HOME
# %config InlineBackend.figure_format = 'retina'

import IPython
isColab = 'google.colab' in str(IPython.get_ipython())
if isColab:
    # !pip install --upgrade openpyxl
    # !pip install --upgrade pandas
    # !pip install --upgrade fugashi[unidic-lite]
    # !pip install --upgrade ipadic
    # !python -m unidic download
    # !pip install transformers
    # !pip install --upgrade jaconv

# %%
if isColab:
    # Google Drive からデータを入手
    # このセルを実行するとブラウザの別タブで Google アカウントへの認証が求められる
    # Google アカウントを選択するとクリデンシャルキーが表示されるので，そのキーを
    # コピーして，このセルの出力欄にある空欄に貼り付けてエンターキー (リターンキー) を押下する
    # Import PyDrive and associated libraries.
    # This only needs to be done once per notebook.
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials

    # Authenticate and create the PyDrive client.
    # This only needs to be done once per notebook.
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

    # 以下実際のデータの情報
    pretrained_models = {
        '2022_0627bert_model.pt': '1oAlxm93un85Y2w2xE92A3i4ZUamma73T',
        '2022_0628bert_model_ja_no_pretrained.pt': '1_J3aymd8-xD8tQtSNkAsoQL0uRIVuk6u',
        '2022_0629bert_model_ja_pretrained.pt':'1ksxLOkj0tO1-DQmKKiLStpx1aNRn17Tp',
        '2022_0630bert_snow_model_no_pretrained': '1OIQwk0RqnFeHj_AmdBK49Ka-aLLgl6SZ',
        '2022_0701bert_snow_model_ja_no_pretrained':'1IMkhjApehc-0R0dSvRPU5HNBzheH7Aks'}
    
    model_name = list(pretrained_models.keys())[0]

    downloaded = drive.CreateFile({'id': pretrained_models[model_name]})
    downloaded.GetContentFile(model_name)
else:
    model_name = '2022_0629bert_snow_pretrained_model.pt'
print(f'model_name:{model_name}')
model = torch.load(model_name)
model.eval();

from transformers import BertJapaneseTokenizer
tknz_model_name = 'cl-tohoku/bert-base-japanese'  # 東北大学乾研による 日本語 BERT 実装
# see https://huggingface.co/sonoisa/sentence-bert-base-ja-mean-tokens-v2
# model_name_ja = 'sonoisa/sentence-bert-base-ja-mean-tokens-v2'  # 東北大学乾研による 日本語 BERT 実装
tknz = BertJapaneseTokenizer.from_pretrained(tknz_model_name)
# Out:
# model_name:2022_0627bert_model.pt

# %% [markdown]
# # やさしい日本語のデータを取得する

# %%
import os
import sys
import requests
import pandas as pd
import jaconv
SNOWs={'T15': {'url':"https://filedn.com/lit4DCIlHwxfS1gj9zcYuDJ/SNOW/T15-2020.1.7.xlsx"},
       'T23': {'url':"https://filedn.com/lit4DCIlHwxfS1gj9zcYuDJ/SNOW/T23-2020.1.7.xlsx"},}


for corpus in SNOWs:
    url = SNOWs[corpus]['url']
    excel_fname = corpus + '-2020.1.7.xlsx'
    if not os.path.exists(excel_fname):
        r = requests.get(url)
        with open(excel_fname, 'wb') as f:
            total_length = int(r.headers.get('content-length'))
            print(f'{excel_fname} をダウンロード中 {total_length} バイト')
            f.write(r.content)

    SNOWs[corpus]['df'] = pd.read_excel(excel_fname, engine='openpyxl')
    SNOWs[corpus]['df'] = SNOWs[corpus]['df'].rename(columns={'#日本語(原文)': 'ja', 
                                                              '#やさしい日本語':'easy_ja',
                                                              '#英語(原文)':'en'})

_snow_sents = SNOWs['T15']['df']['easy_ja'].to_list() + SNOWs['T23']['df']['easy_ja'].to_list()
snow_sents = [jaconv.normalize(line, 'NFKC') for line in _snow_sents]
print(snow_sents[:3])
# Out:
# ['誰が一番に着くか私には分かりません。', '多くの動物が人間によって殺された。', '私はテニス部員です。']

# %%
# %%time
snow_encoded = tknz(snow_sents,return_tensors='pt', padding='longest')
# Out:
# CPU times: user 18 s, sys: 359 ms, total: 18.3 s
# Wall time: 21.1 s

# %%
class SentenceBertJapanese:
    def __init__(self, 
                 model=model,
                 tokenizer=tknz,
                 device=None):
        self.tokenizer = tokenizer
        self.model = model
        self.model.eval()

        if device is None:
            device = "cuda" if torch.cuda.is_available() else "cpu"
        self.device = torch.device(device)
        self.model.to(device)

    def _mean_pooling(self, model_output, attention_mask):
        token_embeddings = model_output[0] #First element of model_output contains all token embeddings
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

    @torch.no_grad()
    def encode(self, sentences, batch_size=8):
        all_embeddings = []
        iterator = range(0, len(sentences), batch_size)
        for batch_idx in iterator:
            batch = sentences[batch_idx:batch_idx + batch_size]

            encoded_input = self.tokenizer.batch_encode_plus(batch, padding="longest", 
                                           truncation=True, return_tensors="pt").to(self.device)
            model_output = self.model(**encoded_input)
            sentence_embeddings = self._mean_pooling(model_output, encoded_input["attention_mask"]).to('cpu')

            all_embeddings.extend(sentence_embeddings)

        # return torch.stack(all_embeddings).numpy()
        return torch.stack(all_embeddings)

# %%
import numpy as np
sbert = SentenceBertJapanese()

# %%
# %%time
# 時間がかかるので最初の 300 文だけ
snow_embeddings = sbert.encode(snow_sents[:300], batch_size=8)
print(f"len(Sentence embeddings):{len(snow_embeddings)}")
# Out:
# len(Sentence embeddings):300
# CPU times: user 27.8 s, sys: 198 ms, total: 28 s
# Wall time: 29 s

# %% [markdown]
# ## 1.1 意味が近い文章をクラスタリング

# %%
from sklearn.cluster import KMeans

num_clusters = 8  # クラスター数は適当に決めました
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(snow_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = [[] for i in range(num_clusters)]
for _id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(snow_sents[_id])

for i, cluster in enumerate(clustered_sentences):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# 
たたかすぎて私には飲むことができない。', '小さな子供は使える言葉が少ない。', 'あなたがいなくて寂しくなるでしょう。', 'あなたの答えは答えになっていない。', 'カードで遊ぶのにもう一人必要だ。', '一生のうちで若く元気な時代なんて1度しかない。', '私は母を助けなければならない。', '怒るな。あなたのためにならないよ。', '話の中心がわかる。', '地球が丸いことのは本当だ。', '彼は何をするにも自ら進んでしない。', 'それを議論する時間はまだ十分ある。', '彼女は8時に朝食を食べに降りてきた。', '私たちは世界平和を目標に進むべきだ。', '今週はしなければならないことでいっぱいだ。', '私はよく冬に雪の上を滑るスポーツをするところにいったものだ。', '払う金があれば、払うのだが。', 'あなたは、朝に食事を取る必要がある。', '彼は絶対に意見を変えない。', '英語の勉強をする気持ちを起こさせる。', '私は次の誕生日で16歳になる。', '私たちは夜にはドアに鍵をかけます。', 'よく注意して見なければダメよ。', '試験がなければ、学生生活はもっと楽しいだろう。', 'あなたはこの機会を利用するべきだ。', '私はこの前の日曜日からずっと忙しい。', '誰も部屋に入れてはならない。', '彼が助けてくれなかったら私は失敗しただろう。', '最初にスープを飲んだ。', '船の旅はとても楽しい。', 'あなたって本当にどうすることもできないね。', '彼女の小説をいずれも読んだわけではない。', 'よく寝た後はずっと気分がよい。', '彼は会議では煙草を吸わないようにしようと提案した。', 'こんな時は、酒を飲んで悪くなった気分をなおすための酒を飲むに限ります。', '彼は煙草を吸うのをやめた。', 'あと少しで間違いをするところだった。', 'あなたには期待しているんだぞ。', '次の年はもっと勉強しなければなりませんよ。', '彼が怠けるのにはもうこれ以上我慢することができない。', '私は泳ぐのを楽しんだ。', '彼はお金についてはとても厳しい。', '結局これではダメだとだけ言っておこう。', 'この服はすぐしわになる。', 'この計画が成功するかどうかまだ分からない。', '明日までに宿題をしなければならない。', '第1に飲むことと食べることに注意しなければならない。', 'もっと仕事に変化があったならばなあ。', '彼の言っていることはある程度本当である。', 'あなたはそんなに急いで行く必要はない。', '失敗してもダメと思ってはならない。', '100万円持っているとしてみよう。', 'きっと私はこの宿題をします。', '彼はすぐ怒るので嫌いだ。', '庭の整備でもしようかな。', 'そのことは否定できない。', '1時間もすれば間違いなく晴れるだろう。', 'この靴は私には合わない。', '彼はおそらくまだ寝ているのだろう。', 'すぐに出発しよう。', '私は危険な状態になるのは好きではない。', '彼は月に1度ロンドンにいく。', '私は学生の誰にも本は貸さない。', '母は料理をするところで忙しくしている。', 'この写真をよく見て私を見つけてみよう。', '彼はとても働いて健康をダメにした。', '何としても戦争はしてはならない。', '彼らは議論をやめることに決めた。', '赤ちゃんを寝させなければならない。', 'バスの止まるところまで走りましょう。', '私はこの本に800円を払った。', 'まずどこへ行くかをみんなで決めよう。', '私は、失敗しないように、頑張って働いた。', 'あなたは最初の計画を実行するべきだ。', '若い時に本当の友達を見つけることは大切だ。', 'すぐにはできない。', '来なさいと言わない限り来ないように。', 'すぐに出発しなければならないでしょう。', '少年が飛ぶのを見てみよう。', '私たちはすぐに出発するつもりだ。', 'チケットがどこにあるかわからなくなってしまったようだ。', '煙草はやめないと彼はいっている。']
#
# Cluster  5
# ['この事実を覚えておいてください。', 'どうぞ午後に私の家へ来てください。', '今のをもう1度言っていただける。', '行きたい学校に入れてよかったね。', '電話を切らずにそのまま待ってください。', '向こうに着いたら手紙をください。', '後で、すぐに電話するわ。', 'ケーキをもっと食べてください。', 'この2つから選びなさい。', '月曜日までにこの仕事を終わらせてください。', 'お会計してください。', '老人を大切にしなさい。', 'なぜ、彼女に直接言わないの。', '冷たい水を持ってきてください。', 'いつでも喜んでお助けします。', 'いつ食事を出したらよいか教えてください。', 'この箱を2階へ運んでもらえますか。', '誰がこの人形を作ったか。', '間違った理解をしないでくれ。', '簡単な英語で言ってください。', '私たちはまだ電話をつけていません。', '今あまりお金を持っていません。', 'そこに名前を書いてください。', 'その手を空へ上げろ。', '私にその辞書を持ってきなさい。', 'コンピューターの使い方を知っていますか。', '順番をお待ちください。', 'そこまで30分以下で行くことができます。', 'あの車を追ってくれ。', '花に触れないでください。', '今夜は私に全てお金を出させてください。', 'この件につき、銀行にご確認いただけますか。', '髪を切ってもらった方がいいよ。', 'それは秘密にしておいた方がいい。', 'お茶を飲みに来てください。', '日本語の新聞を持ってきてくださいますか。', 'あなたが言いたいことは、いったい何ですか。', 'いい感じに入って勝手にやって。', '喜んであなたのパーティーに参加します。', 'ちょっとその絵を見せてください。', 'あなたにこのカメラをあげよう。', '彼に助言をしておきました。', 'こっちの身にもなってよ。', 'これはどんな料理か説明してください。', '彼女の言うことは必ず注意として書いてください。', '小さな庭が付いている家を探してくれませんか。', 'しばらくこの馬に乗ってもいいですか。', '魚の捕まえ方を教えてあげよう。', '私にあなたの名前を教えてください。', '私は1時間につき10ドルもらっています。', 'この机をとっておいてください。', 'もし100万ドルあれば、どうしますか。', 'ケーキのどちらの半分でもとりなさい。', '壁に手をつけ!', '今日の新聞を持ってきて欲しい。', '彼をちょっと待たせておいてください。', 'これとあれの中から1つ選んでください。', 'つまり金が必要なんだ。貸してくれよ!', 'お話させて頂いてもよいでしょうか。', '静かにしてくださいな。', '今夜は明日の準備をしなくちゃ。', '僕の人生に口を出さないでくれ。', '彼は私に野菜を取ってくれた。', '彼は静かにしておいてやろう。', '新しい資料をお送りください。', '窓を閉じてくれませんか。', 'すぐあなたに手紙を書きましょう。', '彼女なら顔を知っています。', '午前中にタクシーを呼んでください。', 'どうぞ道を教えてくださいませんか。', 'これ以上安くしてくれませんか。', '今夜あなたの子供の世話をしましょう。', 'お水を持ってきてください。', 'あなたは両親を尊敬していますか。', 'お医者様に体を調べてもらいなさい。', '次に来る時に、電話をしてください。', 'あなたはそのロープを取らないと約束しなさい。', '景色のよい部屋をお願いします。', '今どこに住んでいますか。', 'その写真を見せてください。', '私に規則を説明してください。']
#
# Cluster  6
# ['私は音楽が好きではありません。', 'その仕事を担当しようかと思っている。', 'サッカーは日本で前よりも今、人気がある。', 'ボブは私の友達です。', '車でどれくらいかかりますか。', 'あなたの国では雪がたくさん降りますか。', 'それについてどう思った。', 'いい年してそんな馬鹿なことはやめろ。', '何時でしょうか。', '彼女は時々お酒を飲む。', '私の計画に反対ですか。', '父は今家にいるだろう。', 'ここでは自由にしていいですよ。', 'これらの靴は私の物だ。', '1週間の休みをとった。', '私は釣りに行くつもりだったのですが。', '何のことを言っているの?', '大阪にはどうやって行くんですか。', 'これらはあなたの物ですか。', 'その帽子は50ドルでした。', 'これは私が欲しいと思った物です。', 'あなたはそれを持っていますか。', '彼は、イギリス人です。', 'あなたは今日明るい顔をしている。', 'あなたは何にするの。', 'この本はここで売られています。', 'これらよりもう少し大きいのはありますか。', '私は彼の計画に賛成します。', '私とテニスをしませんか。', 'ここからタクシーで行くといくらくらいかかりますか。', 'ほかの国にも旅行しますか。', 'やりたいことを全てする時間がないのです。', '誰もが彼女のことを褒める。', '病院まで10マイルもある。', '私は結婚しています。', '私の時計は週に3分遅れる。', 'これまでのところ全てが調子よい。', '何の目的でここまできたのですか。', '私はよく彼を訪ねます。', 'いつあなたはお姉さんと京都へ行きましたか。', '私はあなたを信頼している。', '私の仕事には助ける人がいる。', '時間のある時に私に会いに来なさい。', '列車が入ってくるよ。', '私の娘は深く寝ている。', '実を言うと彼女は僕の妹なんだ。', '私の電話はダメになっている。', 'この犬は誰が世話をするのですか。', '外を歩くことほどいい物はない。', '毎日朝、何時に起きますか。', '私新しい服を買わなくちゃ。', 'あなたはポーラに何と言ったのですか。', '今まで何をしていたのですか。', '何を作るのですか。', 'これが彼らに一番気に入らなかった。', '私は今はなにもすることができません。', '非常の場合は警察を呼びなさい。', '今十分に食べる物ある。', '私は彼女の手のあたたかさを覚えている。', 'もう少し牛の肉をどうですか。', '警察が私を探している。', '私の町は日曜の朝早くは静かだ。', 'いつコンサートのチケットを買ったの。', 'もう1度お互い話をしてはどうかと思うよ。', '氷の上を滑るスポーツの方が好きです。', 'あなたは自分用の部屋を持っていますか。', 'この点で私たちは全くあなたと意見が違います。', '学校に行く一番の理由は何ですか。', '私は部屋を花で飾るのが好きだ。', '今日の仕事はこれまで。', 'この本とあの本とどちらが簡単?', 'これはよい教科書だ。', 'この薬は効果があると思いますよ。', 'いつそれを買ったの。', '日本ではどんな仕事をしていますか。', '明日は、朝の市に行こう。', '映画は10時から始まる。', 'ビルの前に車があります。', 'ケーキをもう少しどうですか。', 'あなたがそんな事を言うとはな。', '彼女はこの町で働いていますか。', '彼はあなたに本当のことを言いましたか。', 'これは何と美しい花でしょう。', '日本語版があったらいいな。', '由美はテニスをしに公園へ行きます。', 'テニスがうまいですね。', '私は「ひさし」と言う名前だ。', '彼女の後にそれを読みなさい。', '彼が勝ちそうだ。', '私は野球の試合を見るのが好きだ。', '母は料理がうまいです。', 'この考え方からすると、あなたの言うことは正しい。', '私からはこれ以上お金は取ることができませんよ。', 'この本は私には簡単に思う。', '私は夏より冬が好きです。', '何か意見がありますか。', '手に何を持っていますか。', 'あなたの国では海の植物を食べますか。', '私はヨーロッパへ2度行った事があります。', '家を手伝わないとならなかったの。', '私はあなたの健康を心配している。', 'この本はあなたのです
なければと思います。', '太陽は地球をあたたかく明るくする。', 'その件に関しては特に意見はありません。', '彼女は20歳といっても認められる。', '彼女は医者になろうと心に決めた。', 'そこへ行く途中私たちは変わりながら運転した。', '東京は日本の他のどの都市よりも大きい。', 'ここは私が生まれた病院です。', '彼女が起こるのはとても当然だ。', '彼らは私に警察へ行くように助言した。', '駅の近くにタクシーに乗る場所があります。', '彼女は夫の死を悲しく思っている。', '太郎は間もなくここへ来ます。', 'あなたにはとても感謝しています。', '昨日学校へ行くことが出来なかったには病気だったからです。', 'メアリーは政治に興味がある。', 'もしあなたが私たちを助けてくれるなら、大変嬉しい。', 'どこへ行っても、彼は必ず友達を作る。', '全ては彼女の返事次第だ。', '彼は馬のように見える。', '出発の準備は全て出来ました。']
#
# Cluster  8
# ['約束を破るべきではありません。', '言っておく物は何もありません。', '対象に当たらなかった。', '怖がるな。', 'そんなに怒る必要はない。', '戦争が起こるかもしれない。', 'もっとゆっくり言ってください。', 'これで僕もようやく浮かばれる。', 'ある意味で、人生は夢にすぎない。', 'お父さんのそばに座りなさい。', 'その事故で交通は止まった。', '私たちはいつかは石油が不足するだろう。', 'そんな急いで食べないで、もうちょっとゆっくり食べようよ。', '短い間の平和の後でまた戦争が起こった。', 'また近いうちにお目にかかりましょう。', 'とても疲れました。', 'こんな長い間待たせてごめんなさい。', '腕を放して。', 'とりあえず、何か食べておきなさい。', '誰でも間違う事はある。', 'ボールを互いに投げよう。', 'ドアはどうしても開かなかった。', '僕にはまるでその理由がわからない。', 'ごゆっくりどうぞ。急ぐ必要はありません。', 'ここが父の生まれたところです。', 'もし見つけられたら彼はひどいことになるだろう。', '次に何が起こるか誰にもわからない。', '歩いて5分以下で着くはずです。', 'あなたには心からすごいと感じるよ。', 'いつでも自分で謝るべきだ。', '間もなく彼らは結婚します。', '一方は知っているがもう一方は知らない。', '昨日の夜は雨が降っていた。', 'すみませんが長くは居られないんですよ。', 'そんなに食べるのは異常だ。', '医者は彼に休むように命令した。', 'その質問から始めましょう。', '彼らはまた尋ねて言った。', 'そのうるさい音は数時間続いた。', '「風と共に去りぬ」を読む。', '老人には親切にしなさい。', '湖は大きさが4828メートルある。', '彼女は事実を知るに至った。', '一人を除いて全員参加した。', 'どんな流れでこうなったのだろう。', '少し横によってください。', '長い休みを楽しみましょう。', '彼女は今にも泣き出しそうだった。', '彼らは急に笑い出した。', '私の中国語は通じなかった。', '何が起こっても、私は驚きません。', '今日夕食食べに行かない?', '人気があろうとなかろうとそれは正しい。', 'それでは行こうか。', 'きっと異常に働いていますよ。', '若いうちに楽しみなさい。', 'この机を移動させなさい。', '予想された天気だと午後は雨ですよ。', 'それはまたの機会にとっておきましょう。', '雨のために試合を止めざるを得なかった。', 'もし明日雨なら試合はなくなります。', 'もしご質問があればお知らせください。', 'とりあえず、ここで待つべきです。', '今すぐ始めよう。', 'こんなこと、日本では起こり得ない。', 'どうしても箱が開かなかった。', '決して彼は相手に尊敬の気持ちを持って行動する男性ではない。', 'なぜこんなに早く来たの?', 'その学生は先生に返事さえしませんでした。', '戻りましたらすぐ電話させます。', '持てば持つほど、人は貧しくなる。', '静かにしていさえすれば、ここに居てもよい。', 'いつでも助けます。', '間もなく試合が始まった。', 'できるなら、あなたにお目にかかりたい。', '今日はあなたついてないねえ。', '雨が3日降り続いた。', '謝る必要はない。', '彼女は間もなく戻るでしょう。', 'ちょっとお待ちいただけますか。', '私たちは互いに心を楽しまさせた。', 'おそらくジェーンは来るだろう。', '彼は除かれた。', '滞在を許可してください。', '簡単に答えるな。', '少し遅れるのも許されなかった。']

# %% [markdown]
# ## 1.2 意味が近い文を検索

# %%
import scipy.spatial

N = 10
queries = snow_sents[:N]  # 試みに最初の N 文 だけやってみる
query_embeddings = sbert.encode(queries).numpy()

closest_n = 5             # 最近隣文 closest_n だけ表示する
for query, query_embedding in zip(queries, query_embeddings):
    distances = scipy.spatial.distance.cdist([query_embedding], snow_embeddings, metric="cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("=" * 78)
    print("Query:", query)
    print("Top 5 most similar sentences:")

    for idx, distance in results[0:closest_n]:
        print(snow_sents[idx].strip(), f"(Score: {distance/2:.4f})")
# Out:
# ==============================================================================
# Query: 誰が一番に着くか私には分かりません。
# Top 5 most similar sentences:
# 誰が一番に着くか私には分かりません。 (Score: 0.0000)
# あなたはポーラに何と言ったのですか。 (Score: 0.0080)
# 私はあなたの言うことが全くわかりません。 (Score: 0.0081)
# 大阪にはどうやって行くんですか。 (Score: 0.0086)
# あなたはそれを持っていますか。 (Score: 0.0088)
# ==============================================================================
# Query: 多くの動物が人間によって殺された。
# Top 5 most similar sentences:
# 多くの動物が人間によって殺された。 (Score: 0.0000)
# ジョンは相手の王を逃げられなくすれば勝つゲームがうまいです。 (Score: 0.0141)
# 彼は私にそこへ行けと命令した。 (Score: 0.0147)
# 彼は何も話すことが出来ないほどに腹を立てていた。 (Score: 0.0149)
# 私の兄は交通事故で死んだ。 (Score: 0.0149)
# ==============================================================================
# Query: 私はテニス部員です。
# Top 5 most similar sentences:
# 私はテニス部員です。 (Score: 0.0000)
# ボブは私の友達です。 (Score: 0.0075)
# 彼は野球の選手です。 (Score: 0.0091)
# 私たち学生はみんな野球が好きだ。 (Score: 0.0103)
# 私は音楽が好きではありません。 (Score: 0.0104)
# ==============================================================================
# Query: エミは幸せそうに見えます。
# Top 5 most similar sentences:
# エミは幸せそうに見えます。 (Score: 0.0000)
# 彼女は元気がなくなった。 (Score: 0.0110)
# 彼は少し疲れているようですね。 (Score: 0.0115)
# 私たちは国際人になりたいと思います。 (Score: 0.0116)
# 彼女は大変忙しかった。 (Score: 0.0117)
# ==============================================================================
# Query: この事実を覚えておいてください。
# Top 5 most similar sentences:
# この事実を覚えておいてください。 (Score: 0.0000)
# 私はその事実を知っていましたよ。 (Score: 0.0076)
# 月曜日までにこの仕事を終わらせてください。 (Score: 0.0088)
# 彼は自分の考えを書いておいた。 (Score: 0.0093)
# この箱を2階へ運んでもらえますか。 (Score: 0.0097)
# ==============================================================================
# Query: 彼女は私たちの世話をしてくれる。
# Top 5 most similar sentences:
# 彼女は私たちの世話をしてくれる。 (Score: 0.0000)
# 私の仕事には助ける人がいる。 (Score: 0.0069)
# この犬は誰が世話をするのですか。 (Score: 0.0077)
# 彼は親切にも私に町を案内してくれた。 (Score: 0.0079)
# 私を助けてくれた時、彼は危険なことをした。 (Score: 0.0079)
# ==============================================================================
# Query: 私たちは国際人になりたいと思います。
# Top 5 most similar sentences:
# 私たちは国際人になりたいと思います。 (Score: 0.0000)
# 彼女はお金がなく生活が大変な人たちの味方です。 (Score: 0.0079)
# 彼はあなたの成功を見て自分もそうなりたいと思っている。 (Score: 0.0079)
# 彼はあなたにここにいてもらいたいと思っている。 (Score: 0.0081)
# 私には外国人の友達が二人います。 (Score: 0.0082)
# ==============================================================================
# Query: 約束を破るべきではありません。
# Top 5 most similar sentences:
# 約束を破るべきではありません。 (Score: 0.0000)
# 私は音楽が好きではありません。 (Score: 0.0101)
# 言っておく物は何もありません。 (Score: 0.0115)
# 彼女にはよくある事だが、約束を破った。 (Score: 0.0123)
# 父は私が外国へ行くことを許した。 (Score: 0.0126)
# ==============================================================================
# Query: 道路を渡る時は車に注意しなさい。
# Top 5 most similar sentences:
# 道路を渡る時は車に注意しなさい。 (Score: 0.0000)
# 彼は先生の注意を大切にした。 (Score: 0.0096)
# 父は私が外国へ行くことを許した。 (Score: 0.0110)
# 彼女は彼に自転車を使うように言った。 (Score: 0.0110)
# 時間のある時に私に会いに来なさい。 (Score: 0.0115)
# ==============================================================================
# Query: 私には生きる上での価値がない。
# Top 5 most similar sentences:
# 私には生きる上での価値がない。 (Score: 0.0000)
# 彼女はお金がなく生活が大変な人たちの味方です。 (Score: 0.0082)
# 私の仕事には助ける人がいる。 (Score: 0.0088)
# 私たちにまだ多くの仕事がある。 (Score: 0.0093)
# 私たちは自分だけのために生まれたのではない。 (Score: 0.0098)

# %% [markdown]
# ## 1.3 文の意味関係の可視化 tSNE による散布図
#
# 以下は colab ではメモリ不足で動作しません。
# 後日公開させていただきます。

# %%
# !git clone https://github.com/ShinAsakawa/ccap.git
try:
    import japanize_matplotlib
except ImportError:
    # !pip install japanize_matplotlib

if isColab:
    #!pip install mecab-python3 unidic-lite
    #https://colab.research.google.com/github/himkt/konoha/blob/master/example/Konoha_Example.ipynb#scrollTo=wBxBPzHtYYXQ
    # !sudo apt update -qy && apt install -qy mecab libmecab-dev mecab-ipadic-utf8 > /cev/null
    # !pip install -q konoha[all]  

    # 形態素分析ライブラリーMeCab と 辞書(mecab-ipadic-NEologd)のインストール 
    # https://qiita.com/jun40vn/items/78e33e29dce3d50c2df1
    # !apt-get -q -y install sudo file mecab libmecab-dev mecab-ipadic-utf8 git curl python-mecab > /dev/null
    # !git clone --depth 1 https://github.com/neologd/mecab-ipadic-neologd.git > /dev/null 
    # !echo yes | mecab-ipadic-neologd/bin/install-mecab-ipadic-neologd -n > /dev/null 2>&1
    # !pip install mecab-python3 > /dev/null

    # !ln -s /etc/mecabrc /usr/local/etc/mecabrc

# %%
from ccap import tsne
X = tsne.tsne(snow_embeddings.clone().numpy())
# Out:
# Preprocessing the data using PCA...
