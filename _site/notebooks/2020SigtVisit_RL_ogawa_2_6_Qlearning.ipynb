# %% [markdown]
# <a href="https://colab.research.google.com/github/ShinAsakawa/ShinAsakawa.github.io/blob/master/notebooks/2020SigtVisit_RL_ogawa_2_6_Qlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q学習のデモ
#
#  <a href="mailto:asakawa@ieee.org">浅川伸一</a>
#
# 本ファイルは小川雄太郎の「[つくりながら学ぶ！深層強化学習](https://www.amazon.co.jp/dp/4839965625/)」(マイナビ出版 2018/6/28)
# の 2.2. 迷路とエージェントを実装，にでてくる[2.6 Q学習で迷路を攻略](https://github.com/YutaroOgawa/Deep-Reinforcement-Learning-Book/blob/master/program/2_6_Qlearning.ipynb) です。
#
# すぐれた教科書を書かれた小川さんに感謝いたします

# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
# 初期の方策を決定するパラメータtheta_0を設定

# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義


def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 初期の行動価値関数Qを設定

[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0 * 0.1
# *theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %%
# ε-greedy法を実装


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 行動aの方向

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return s_next

# %%
# Q学習による行動価値関数Qの更新


def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %%
# Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Q学習で迷路を解く

eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

V = []  # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める

while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに行動価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値関数の変化を出力
    v = new_v
    V.append(v)  # このエピソード終了時の状態価値関数を追加

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.16951446744472576
# 迷路を解くのにかかったステップ数は410です
# エピソード:2
# 0.10976812724807342
# 迷路を解くのにかかったステップ数は36です
# エピソード:3
# 0.09501842141063963
# 迷路を解くのにかかったステップ数は32です
# エピソード:4
# 0.0917391934180346
# 迷路を解くのにかかったステップ数は4です
# エピソード:5
# 0.0907858943050334
# 迷路を解くのにかかったステップ数は4です
# エピソード:6
# 0.08983852503827164
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.08888327111299751
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.08790612731269593
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.08689387447460506
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.08583473165676676
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.08471875708436344
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.08353805748991022
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.08228685400201431
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.08096144322428679
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.07956008427517042
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.07808283607132298
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.07653136381073354
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.07490872925895332
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.07321917590310531
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.07146791717837041
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.06966093367592652
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.06780478341311177
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.06590642780429998
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.06397307484602968
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.0620120401646673
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.0600306259210944
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.0580360170842778
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.05603519424057116
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.0540348618703394
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.052041390874969895
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.050060774056552515
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.04809859322390703
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.04615999660950215
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.044249685321859245
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.0423719076189214
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.04053045986298398
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.038728693101831746
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.036969524309594826
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.035255451411326244
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.033588571304980996
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.03197060018155323
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.030402895527285367
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.028886479270232635
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.027422061606441783
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.026010065108306668
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.024650648779143247
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.023343731773730503
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.022089016554628582
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.02088601129875478
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.019734051408224706
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.01863232001421322
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.017579867392871762
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.016575629238533174
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.015618443761871936
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.014707067599756374
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.013840190539525343
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.013016449073691372
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.0122344388119221
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.011492725785834712
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.01078985668896515
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.010124368099433845
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.009494794736582768
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.008899676805386392
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.008337566483917258
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.007807033609761094
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.007306670621137212
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.006835096807743302
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.006390961925114569
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.005972949224651858
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.00557977794954112
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.005210205344613472
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.004863028225856381
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.00453708415282883
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.004231252244721095
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.003944453678243587
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.0036756519029976786
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0034238526074626963
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.0031881034662945007
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0029674936972365895
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0027611534536652327
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.002568253076583149
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.002388002227792896
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0022196489239905137
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.0020624784896597914
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0019158124448789282
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0017790073425186792
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.001651453567773964
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.001532574111546281
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.0014218233278846526
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0013186856844723538
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.0012226745140333506
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.0011333307735105214
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0010502218169319288
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.000972940187033311
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0009011024299296899
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.0008343479364381068
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.0007723378130194414
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.0007147537847427277
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.0006612971321765526
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0006116876636529378
# 迷路を解くのにかかったステップ数は4です

# %%
# 状態価値の変化を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img21b26dff5017448fb775eabfc1917120">
#     <br>
#     <input id="_anim_slider21b26dff5017448fb775eabfc1917120" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim21b26dff5017448fb775eabfc1917120.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim21b26dff5017448fb775eabfc1917120.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select21b26dff5017448fb775eabfc1917120" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img21b26dff5017448fb775eabfc1917120";
#     var slider_id = "_anim_slider21b26dff5017448fb775eabfc1917120";
#     var loop_select_id = "_anim_loop_select21b26dff5017448fb775eabfc1917120";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAFMxJREFUeJzt3XuUHnV9x/H3Jps7CQEDzxKRLGC4\
# C3KISORSRNEj0IOg4qX1AqJFFK0torUVLz1SLWql2hKvx3pBpeIF5WjVKh6DVQmgVIyceolR8VmN\
# 5CaXEOTpH99Z99nNPtlsfHbm+8y+X+c8Z3dn5sn58tvh8/zmO7Mzfa1Wq4UkKZ0ZVRcgSRqfAS1J\
# SRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQ\
# kpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSU\
# AS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1JSRnQkpSUAS1J\
# SRnQkpSUAS1JSfVXXcDuWLJkCYODg1WXIalm1q1bx4YNG6ou4496MqAHBwdZs2ZN1WVIqpkVK1ZU\
# XcIotjgkKSkDWpKS6skWx3gGBm5gaGhb1WXUSqMxh2bzzI7rHfPum3jM1zM09FCJFdVfozGDZvOA\
# qssYV21m0AZF9000po5590085oZzt2Ue09oEtCTVjQEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKU\
# lAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEt\
# SUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUlAEtSUkZ0JKUVH/VBdTTZuCTwK3ARmAB\
# cABwDnAM0AKuBb4C3AMsBy4sttHkTTTe3wa+DPwM2AK8ETiqkkrr5XfAO4GvA78FFgKHAhcBJwBv\
# B24E1gN7ACuBy4CHV1BrbzKgp8SVwAPAxcAAEQp3AFuL9Z8FrgdeRuys1wJvAt4FzCu72BqYaLzv\
# Bw4DTiHGWN3xEmJs3wosIwL7O8Am4D7gB8Q+fjjxu3gz8ALgixg9u8ZR6rp7gLXA5cDRxbJ9gUcW\
# 37eALxCzu5XFskuAC4BvAk8qrdJ6mGi8AU4tvm4pr6za2wLcDHwEOLFYtj9xxDLso2PecwWxf/+Y\
# +MDUROxBd93c4rWGmNWNNUTMMB7dtmwOcARw55RXVz8TjbemxnyilfRVYNsuvuf3xdc9p6SiOnIG\
# 3XUzicO6VUSP+UBitrASOIQIZ9hxJ11MHCJqciYab02NfqK19HfAx4EjgeOAM4Bjx9n+AaLF8QRg\
# v5Jq7H0G9JRYSeysa4lZ8feInvNziB1Z3bWz8X5ahXXV3VOA04DvArcB3wDeD1wKvLRtuweBVxJt\
# kfeVXGNvs8UxZWYT/bjziN7bE4iTgYuK9ZvHbL8J2Ku06uqn03hvr7KoaWAOcDLwcuA6YvyvYqTd\
# 9GCx7kfAx3AfnxwDujT7A38gWhuLge+3rXuAmP0dWkFddTU83gZ0uZYTobyNGPtLiHD+OLBPhXX1\
# JlscXbcVeBtx6LeMuGzuJ8DngEcRJ1bOAj5NXGK3FPgUcaLr5Arq7XUTjff8YpsNxBUfAE3i97AY\
# Z3S7ayPRxngG0fPfA7gdeA/wOOL3cHGx7P1AH3GtNMT10nNLrrc3GdBdN5c4OXUDEQTbgb2Bk4Cn\
# F9s8lZg1v4+RP1S5HK+B3h27Mt43A//W9p6ri6/nAc8sp8zamU+cDPwQsI7YnweAs4mTtk3ipC3A\
# n49575WM/G60MwZ0180C/qJ4ddJHBIPh8KfblfE+rXipe+YArype41lM/OWm/hT2oCUpKQNakpIy\
# oCUpKQNakpIyoCUpKQNakpIyoCUpKQNakpIyoCUpKQNakpLyT713y6eIx1PNKF4
